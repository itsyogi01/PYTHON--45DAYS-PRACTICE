# %% [markdown]
# <a href="https://colab.research.google.com/github/itsyogi01/PYTHON--45DAYS-PRACTICE/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# BASIC IF ELSE EXAMPLE
num = 5
if(num > 0):
    print("positive number")
else:
    print("negative number")
# Out:
# positive number

# %%
0p0# IF ELIF ELSE
marks = 85
if marks >= 90:
    print("grade A")
elif marks >= 75:
    print("grade B")
elif marks >= 60:
    print("grade c")
else:
    print("fail")
# Out:
# grade B

# %%
# NESTED IF - ELSE
age = 18
gender = "male"
if(age >= 18):
    if(gender == "male"):
        print("Adult Male")
    else:
        print("Adult Female")
else:
    print("Minor")
# Out:
# Adult Male

# %%
# TERNARY OPERATOR
num = 10
result = "Even" if num%2 == 0 else "odd"
print(result)
# Out:
# Even

# %%
# largest of two number
a,b = 10,30
# if a>b:
#     print("a is largest number")
# else:
#     print("b is larest number")

#  by using ternary operator
result = a if a > b else b
print(result)
# Out:
# 30

# %%
# LARGEST OF THREE NUMBER
num1 = int(input("Enter the first number : "))
num2 = int(input("Enter the second number : "))
num3 = int(input("Enter the third number : "))
# if num1>num2:
#   if num1>num3:
#       print("number 1  is greatest number")
#   else:
#       print("number 3 is greatest number")
# elif num2>num1:
#   if num2 > num3:
#       print("number 2 is the greatest number")
#   else:
#       print("number 3 is thee greatest number")
# else:
#     print("number 3 is greatest number")

# using and operater
if num1>num2 and num1>num3:
    print("number 1 is greatest number")
elif num2>num1 and num2>num3:
    print("number two is the greatest number")
else:
    print("number 3 is the greatest number")
# Out:
# Enter the first number : 45
# Enter the second number : 88
# Enter the third number : 66
# number two is the greatest number

# %%
# IDENTIFY  A YEAR IS LEAP YEAR OR NOT
year = int(input("Enter a year : "))
if(year%400 == 0) or (year%4 == 0 and year%100 != 0):
    print("leap year")
else:
    print("Not a leap year")
# Out:
# Enter a year : 1900
# Not a leap year

# %%
# voting eligibility
Age = int(input("Enter the Age : "))
if(Age>=18):
    print("Eligiable for vote")
else:
     print("Not eligiable")
# Out:
# Enter the Age : 19
# Eligiable for vote

# %%
#   PASSWORD CHECKING
password = "Nikita@123"
if password == "Nikita@123":
    print("Login successfully")
else:
    print("wrong password")
# Out:
# Login successfully

# %%
# CHECK A NUMBER IS POSITIVE , NEGATIVE ,ZERO
num = int(input("Enter a number : "))
if num > 0:
    print("positive number")
elif num == 0:
    print("number is equal top zero")
else:
    print("negative number")
# Out:
# Enter a number : 45
# positive number

# %%
# CHECK A CHARACTER IS VOWEL OR CONSONANT
ch = "a"
if ch in "aeiouAEIOU":
    print("vowel")
else:
    print("consonant")
# Out:
# vowel

# %%
# check a number is divisible by 5 and 11
num = 55
if num%5==0 and num%11==0:
    print("number is divisible by both 5 and 11")
else:
    print("not divisible")
# Out:
# number is divisible by both 5 and 11

# %%
# SIMPLE CALCULATOR\
num1 = int(input("Enter a first number"))
num2 = int(input("Enter a second number"))
operator = input("Enter a operater")
if operator=="+":
    print(num1+num2)
elif operator == "-":
    print(num1-num2)
elif operator == "*":
    print(num1*num2)
elif operator == "/":
    print(num1/num2)
elif operator == "**":
    print(num1**num2)
elif operator == "//":
    print(num1//num2)
elif operator == "%":
    print(num1%num2)
else:
    print("Invalid operator")
# Out:
# Enter a first number2
# Enter a second number4
# Enter a operater**
# 16
