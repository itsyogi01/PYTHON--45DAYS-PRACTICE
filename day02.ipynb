# %% [markdown]
# <a href="https://colab.research.google.com/github/itsyogi01/PYTHON--45DAYS-PRACTICE/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# OPERATERS IN PYTHON
# Aoirthmetic operater
a = 10
b = 3

print(a + b)   # Addition → 13
print(a - b)   # Subtraction → 7
print(a * b)   # Multiplication → 30
print(a / b)   # Division → 3.333...
print(a // b)  # Floor Division → 3
print(a % b)   # Modulus → 1
print(a ** b)  # Exponent → 1000
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
# Relational operater
x = 5
y = 10

print(x == y)   # Equal → False
print(x != y)   # Not Equal → True
print(x > y)    # Greater → False
print(x < y)    # Less → True
print(x >= y)   # Greater or Equal → False
print(x <= y)   # Less or Equal → True
# Out:
# False
# True
# False
# True
# False
# True

# %%
# Logical operater
a = True
b = False

print(a and b)  # AND → False
print(a or b)   # OR → True
print(not a)    # NOT → False
# Out:
# False
# True
# False

# %%
# Assignment operater
x = 5
x += 3   # x = x + 3 → 8
x -= 2   # x = x - 2 → 6
x *= 4   # x = x * 4 → 24
x /= 6   # x = x / 6 → 4.0
x %= 3   # x = x % 3 → 1
print(x)
# Out:
# 1.0

# %%
# bitwise operater
a = 5   # 0101
b = 3   # 0011

print(a & b)   # AND → 1 (0001)
print(a | b)   # OR → 7 (0111)
print(a ^ b)   # XOR → 6 (0110)
print(~a)      # NOT → -6
print(a << 1)  # Left Shift → 10 (1010)
print(a >> 1)  # Right Shift → 2 (0010)

# %%
# membership operater
list1 = [1, 2, 3, 4]

print(2 in list1)      # True
print(5 not in list1)  # True

# %%
# identity  operater
x = [1, 2, 3]
y = [1, 2, 3]
z = x

print(x is y)      # False (different objects)
print(x is z)      # True (same object)
print(x is not y)  # True

# %%
# --------------------------Type Conversion---------------------------------------------
# implicit type conversion.
x = 10
y = 2.3
result = x+y
print(result)
print(type(result))
# Out:
# 12.3
# <class 'float'>

# %%
# String to interger
# Explicit type conversion
num = "100"
num = int(num)
print(num + 20)
print(type(num))

# float to interger
f = 3.14
print(int(f))

# Interger to string
n = 25
n = str(n)
print(n)
print(type(n))

# list to tuple
lst = [1,2,3]
tpl = tuple(lst)
print(tpl)
print(type(tpl))


# Tuple to setd
t = (1,2,3,4,4)
s = set(t)
print(s)
print(type(s))
# Out:
# 120
# <class 'int'>
# 3
# 25
# <class 'str'>
# (1, 2, 3)
# <class 'tuple'>
# {1, 2, 3, 4}
# <class 'set'>

# %%
# -----------------------String---------------------------
str1 = "hello"
str2 = "world"
print(str1 + str2)
print(len(str1))


# Indexing
str = "Nikita"
ch = str[1]
print(ch)
print(str[-1])
print(str[-3])


# slicing in python
str = "Rupesh yogi"
print(str[0:3])
print(str[:4])
print(str[1:])
print(str[1:len(str)])
print(str[-3:-1])
print(str[-4:-1])
# Out:
# helloworld
# 5
# i
# a
# i
# Rup
# Rupe
# upesh yogi
# upesh yogi
# og
# yog

# %%
str1 = "i am Rupesh"
print(str1.endswith("sh"))
print(str1.capitalize())
print(str1.replace("Rupesh","Nikita"))
print(str.find("Rupesh"))
print(str.count("a"))
# Out:
# True
# I am rupesh
# i am Nikita
# 5
# 1

# %%
# ------------------ List------------------------
my_list = [7, "Rupesh", 6, True]
print(my_list)
empty_list = []
number = [1,2,3,4,5,6,7,8]
mixed = [1,2.3,"radha"]
print(mixed[0])
print(mixed[-1])
print(number[5])


# -------------list operation--------------
a = [1,2,3,4]
b = ["rupesh","nikita","sonu",3.5]
c = a+b
print(c)
print(a)
print(b)
print(a+b)
print(a * 2)


empty_list = []
print(empty_list)

print(not empty_list)
# Out:
# [7, 'Rupesh', 6, True]
# 1
# radha
# 6
# [1, 2, 3, 4, 'rupesh', 'nikita', 'sonu', 3.5]
# [1, 2, 3, 4]
# ['rupesh', 'nikita', 'sonu', 3.5]
# [1, 2, 3, 4, 'rupesh', 'nikita', 'sonu', 3.5]
# [1, 2, 3, 4, 1, 2, 3, 4]
# []
# True

# %%
detail = ["rupesh yogi",21,7,"arya"]
print(detail)
detail.append(50)
print(detail)
detail.insert(1,77)
print(detail)
detail.remove(7)
print(detail)
print(detail.count("rupesh yogi"))
print(detail.index("arya"))
a = [10,20,30,40,22]
a.sort()
print(a)
a.reverse()
print(a)
copy = detail.copy()
print(detail)
detail.pop(1)
print(detail)
detail.clear()
print(detail)
# Out:
# ['rupesh yogi', 21, 7, 'arya']
# ['rupesh yogi', 21, 7, 'arya', 50]
# ['rupesh yogi', 77, 21, 7, 'arya', 50]
# ['rupesh yogi', 77, 21, 'arya', 50]
# 1
# 3
# [10, 20, 22, 30, 40]
# [40, 30, 22, 20, 10]
# ['rupesh yogi', 77, 21, 'arya', 50]
# ['rupesh yogi', 21, 'arya', 50]
# []

# %%
# -----------------LIST SLICING------------------
L = [10,17,"RADHA",9.81,"B.TECH"]
print(L[1:4])
print(L[:3])
print(L[2:])
print(L[1:len(L)])
L[0] = 100
print(L)
# Out:
# [17, 'RADHA', 9.81]
# [10, 17, 'RADHA']
# ['RADHA', 9.81, 'B.TECH']
# [17, 'RADHA', 9.81, 'B.TECH']
# [100, 17, 'RADHA', 9.81, 'B.TECH']

# %%
# ////--------------------------TUPLES IN PYTHON------------------------/////
my_tuple = (10,"rupesh",7,True)
print(my_tuple)
tup = ()
print(type(tup))
tup1 = (10)
print(type(tup1))
tup1 = (10,)
print(type(tup1))
tup2 = (10,20,30)
print(tup2)
print(type(tup2))
# Out:
# (10, 'rupesh', 7, True)
# <class 'tuple'>
# <class 'int'>
# <class 'tuple'>
# (10, 20, 30)
# <class 'tuple'>

# %%
A =(10,20,"rupesh")
# A[1] = 90 not allowed in python immutable
empty_tuple = ()
single = (5,)                # without comma interger ci=onsider kar lega
numbers = (1, 2, 3, 4, 5)    # integer tuple
mixed = (1, "hello", 3.14)
print(mixed[0])
print(mixed[1])


# tuple operation
a = (1, 2, 3)
b = (4, 5)

print(a + b)   # Concatenation → (1,2,3,4,5)
print(a * 2)   # Repeat → (1,2,3,1,2,3)



# tuple method
tup = [1,1,2,2,3,3,3,5,5,7,8,]
print(tup.count(2))
print(tup.index(3))
# List → mutable → can add, remove, or sort elements.
# Tuple → immutable → once created, elements cannot be changed,
#  so modification methods are not available
# Out:
# 1
# hello
# (1, 2, 3, 4, 5)
# (1, 2, 3, 1, 2, 3)
# 2
# 4
